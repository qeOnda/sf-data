# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('https://data.sfgov.org/resource/5cei-gny5.csv')
fd = pd.read_csv('https://data.sfgov.org/resource/wmam-7g8d.csv')

# %%
df.head()
# Out:
#   eviction_id                                 address           city state  \
# 0     M200682  300 Block Of Executive Park  Boulevard  San Francisco    CA
# 1     M200677           800 Block Of Van Ness  Avenue  San Francisco    CA
# 2     M200680         900 Block Of Divisadero  Street  San Francisco    CA
# 3     M200678             900 Block Of Sutter  Street  San Francisco    CA
# 4     M200681           1100 Block Of Mission  Street  San Francisco    CA
#
#      zip                file_date  non_payment  breach  nuisance  illegal_use  \
# 0  94134  2020-05-06T00:00:00.000        False   False      True        False
# 1  94109  2020-05-06T00:00:00.000        False    True     False        False
# 2  94115  2020-05-06T00:00:00.000        False   False      True        False
# 3  94109  2020-05-06T00:00:00.000        False   False      True        False
# 4  94103  2020-05-06T00:00:00.000        False    True     False        False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   eviction_id                  1000 non-null   object
#  1   address                      1000 non-null   object
#  2   city                         1000 non-null   object
#  3   state                        1000 non-null   object
#  4   zip                          1000 non-null   int64
#  5   file_date                    1000 non-null   object
#  6   non_payment                  1000 non-null   bool
#  7   breach                       1000 non-null   bool
#  8   nuisance                     1000 non-null   bool
#  9   illegal_use                  1000 non-null   bool
#  10  failure_to_sign_renewal      1000 non-null   bool
#  11  access_denial                1000 non-null   bool
#  12  unapproved_subtenant         1000 non-null   bool
# ...

# %%
eviction_zip = df[['eviction_id', 'zip']].groupby(by = 'zip', as_index=False).count().sort_values('eviction_id', ascending=False)
eviction_zip.rename(columns = {'eviction_id': 'evictions'}, inplace=True)
eviction_zip.head(6)
# Out:
#       zip  evictions
# 21  94132        184
# 6   94109        102
# 7   94110         93
# 0   94102         77
# 1   94103         67
# 9   94112         66

# %%
eviction_hood = df[['eviction_id', 'neighborhood']].groupby(by = 'neighborhood', as_index=False).count().sort_values('eviction_id', ascending=False)
eviction_hood.rename(columns = {'eviction_id': 'evictions', 'neighborhood': 'neighborhood'}, inplace=True)
eviction_hood.head(10)
# Out:
#        neighborhood  evictions
# 12        Lakeshore        180
# 15          Mission        109
# 31       Tenderloin         78
# 30  Sunset/Parkside         53
# 17         Nob Hill         46
# 22   Outer Richmond         41
# 8      Hayes Valley         35
# 29  South of Market         35
# 27     Russian Hill         31
# 4         Excelsior         31

# %%
alt.Chart(eviction_hood).mark_bar().encode(x = alt.X('neighborhood', sort='-y'), y= 'evictions')
# Out:
# alt.Chart(...)

# %%
df.zip.value_counts().sort_values().plot(kind = 'bar')

# %%
zips = [94132, 94109, 94110, 94102, 94103, 94112]

# %%
top6 = df[df.zip.isin(zips)]

# %%
top6.shape
# Out:
# (589, 43)

# %%
df.zip.nunique()
# Out:
# 24

# %%
top6.non_payment.value_counts()
# Out:
# False    560
# True      29
# Name: non_payment, dtype: int64

# %%
top6.neighborhood.value_counts()
# Out:
# Lakeshore                     180
# Mission                       108
# Tenderloin                     78
# Nob Hill                       41
# South of Market                33
# Excelsior                      28
# Oceanview/Merced/Ingleside     22
# Hayes Valley                   21
# Russian Hill                   19
# Bernal Heights                 16
# Outer Mission                  14
# Pacific Heights                 5
# Western Addition                5
# West of Twin Peaks              2
# Marina                          2
# Castro/Upper Market             2
# Noe Valley                      2
# Bayview Hunters Point           1
# Glen Park                       1
# Mission Bay                     1
# Name: neighborhood, dtype: int64

# %%
df.neighborhood.value_counts().head(15)
# Out:
# Lakeshore                         180
# Mission                           109
# Tenderloin                         78
# Sunset/Parkside                    53
# Nob Hill                           46
# Outer Richmond                     41
# South of Market                    35
# Hayes Valley                       35
# Excelsior                          31
# Russian Hill                       31
# Haight Ashbury                     28
# Bayview Hunters Point              27
# Castro/Upper Market                27
# Financial District/South Beach     25
# Oceanview/Merced/Ingleside         22
# Name: neighborhood, dtype: int64

# %%
first = top6[top6.zip == 94132]
first = first[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]
first1 = first.melt(var_name='columns', value_name='index')
pd.crosstab(index=first1['index'], columns=first1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False              184       7                  183               184
# True                 0     177                    1                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False           184          184                   184
# True              0            0                     0
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                        184                  184          183
# True                           0                    0            1
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False              184               184          184       181          184
# True                 0                 0            0         3            0
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
second = top6[top6.zip == 94109]
second = second[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]
second1 = second.melt(var_name='columns', value_name='index')
pd.crosstab(index=second1['index'], columns=second1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False              102      86                   85               102
# True                 0      16                   17                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False           102          102                   102
# True              0            0                     0
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                        102                  102          100
# True                           0                    0            2
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False              101               102           93        47          102
# True                 1                 0            9        55            0
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
third = top6[top6.zip == 94110]
third = third[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]
third1 = third.melt(var_name='columns', value_name='index')
pd.crosstab(index=third1['index'], columns=third1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               92      78                   90                93
# True                 1      15                    3                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            93           93                    72
# True              0            0                    21
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         93                   93           93
# True                           0                    0            0
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               92                93           87        67           92
# True                 1                 0            6        26            1
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
fourth = top6[top6.zip == 94102]
fourth = fourth[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]
fourth1 = fourth.melt(var_name='columns', value_name='index')
pd.crosstab(index=fourth1['index'], columns=fourth1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               77      68                   70                77
# True                 0       9                    7                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            77           77                    76
# True              0            0                     1
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         77                   77           77
# True                           0                    0            0
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               76                77           70        32           76
# True                 1                 0            7        45            1
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
fifth = top6[top6.zip == 94103]
fifth = fifth[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]
fifth1 = fifth.melt(var_name='columns', value_name='index')
pd.crosstab(index=fifth1['index'], columns=fifth1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               66      54                   67                67
# True                 1      13                    0                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            66           67                    61
# True              1            0                     6
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         67                   67           64
# True                           0                    0            3
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               67                67           65        29           66
# True                 0                 0            2        38            1
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
sixth = top6[top6.zip == 94112]
sixth = sixth[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]
sixth1 = sixth.melt(var_name='columns', value_name='index')
pd.crosstab(index=sixth1['index'], columns=sixth1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               64      57                   66                66
# True                 2       9                    0                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            66           66                    54
# True              0            0                    12
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         66                   66           66
# True                           0                    0            0
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               66                66           61        54           62
# True                 0                 0            5        12            4
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
allsix = top6[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]
allsix1 = allsix.melt(var_name='columns', value_name='index')
pd.crosstab(index=allsix1['index'], columns=allsix1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False              585     350                  561               589
# True                 4     239                   28                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False           588          589                   549
# True              1            0                    40
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                        589                  589          583
# True                           0                    0            6
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False              586               589          560       410          582
# True                 3                 0           29       179            7
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
df.file_date = pd.to_datetime(df.file_date)

# %%
df.file_date
# Out:
# 0     2020-05-06
# 1     2020-05-06
# 2     2020-05-06
# 3     2020-05-06
# 4     2020-05-06
#          ...
# 995   2019-06-24
# 996   2019-06-24
# 997   2019-06-24
# 998   2019-06-24
# 999   2019-06-24
# Name: file_date, Length: 1000, dtype: datetime64[ns]

# %%
evict_months = df.eviction_id.groupby(by = df.file_date.dt.month).count()
evict_months
# Out:
# file_date
# 1      97
# 2     111
# 3      67
# 4      32
# 5      15
# 6      53
# 7     134
# 8     147
# 9     105
# 10     88
# 11     78
# 12     73
# Name: eviction_id, dtype: int64

# %%
evict_day = df[['eviction_id', 'file_date']].groupby(by = 'file_date', as_index=False).count()
evict_day.rename(columns = {'eviction_id': 'evictions'}, inplace=True)
evict_day.head()
# Out:
#    file_date  evictions
# 0 2019-06-24          5
# 1 2019-06-25          4
# 2 2019-06-26          5
# 3 2019-06-27         34
# 4 2019-06-28          5

# %%
alt.Chart(
    evict_day,
    padding = 10,
    title = 'Evictions by day of year'
).mark_line(
    interpolate = 'basis',
    color = 'blue'
).encode(
    x = alt.X(
        'file_date:T',
        axis = alt.Axis(
            title = 'Day of year',
            format = '%b-%e',
            labelAngle = -90, 
            labelFlush = True, 
            tickCount = 26, 
            grid = False)),
        y = alt.Y(
            'evictions:Q',
            axis =alt.Axis(
            title = 'Evictions'))
    )
# Out:
# alt.Chart(...)

# %%
evict_day[evict_day['evictions'] >= 10]
# Out:
#      file_date  evictions
# 3   2019-06-27         34
# 13  2019-07-15         14
# 18  2019-07-22         10
# 23  2019-07-29         33
# 27  2019-08-05         17
# 32  2019-08-12         10
# 35  2019-08-15         21
# 43  2019-08-28         29
# 54  2019-09-13         14
# 60  2019-09-23         10
# 63  2019-09-26         14
# 74  2019-10-15         19
# 86  2019-11-04         11
# 99  2019-11-25         10
# 102 2019-12-02         12
# 110 2019-12-16         12
# 128 2020-01-16         10
# 148 2020-02-14         18
# 156 2020-02-28         30

# %%
##TO DO###file_date##review by zip code - check reasons for notice
## review by neighborhoods - check reasons for notice (top 6 of both about 50 percent of notices..)
##map top 6 by neighborhood and zip

# %%
fd.analysis_neighborhood.value_counts()
# Out:
# Mission                           109
# Sunset/Parkside                    79
# Castro/Upper Market                61
# Outer Richmond                     60
# Noe Valley                         52
# Pacific Heights                    51
# Haight Ashbury                     46
# Marina                             43
# Excelsior                          40
# Hayes Valley                       40
# Bernal Heights                     36
# Inner Richmond                     31
# Inner Sunset                       30
# Nob Hill                           29
# Western Addition                   28
# West of Twin Peaks                 27
# Russian Hill                       25
# Potrero Hill                       25
# Lone Mountain/USF                  23
# Bayview Hunters Point              21
# Outer Mission                      19
# North Beach                        18
# Oceanview/Merced/Ingleside         17
# Visitacion Valley                  14
# South of Market                    13
# ...

# %%
mish = fd[fd.analysis_neighborhood == 'Mission']

# %%
mish.buyout_amount.sort_values(ascending=False)
# Out:
# 40     310000.00
# 703    155000.00
# 61     150000.00
# 553    130000.00
# 698    128000.00
#          ...
# 447      6990.00
# 111      6083.76
# 878      5100.00
# 162      5000.00
# 464          NaN
# Name: buyout_amount, Length: 109, dtype: float64

# %%
lots = fd[fd.buyout_amount == 100000]

# %%
lots.analysis_neighborhood.value_counts()
# Out:
# Mission                3
# Marina                 3
# Castro/Upper Market    2
# Twin Peaks             1
# South of Market        1
# Portola                1
# Noe Valley             1
# Pacific Heights        1
# Name: analysis_neighborhood, dtype: int64

# %%
evictions_reasons = pd.pivot_table(df, 
                                  columns = ['non_payment','breach','nuisance'],
                                  index = 'neighborhood',
                                  values = 'eviction_id',
                                  aggfunc = 'count')
evictions_reasons
# Out:
# non_payment                    False                    True
# breach                         False        True        False True
# nuisance                       False True   False True  False False
# neighborhood
# Bayview Hunters Point            9.0   7.0    6.0   2.0   3.0   NaN
# Bernal Heights                  13.0   1.0    1.0   1.0   NaN   NaN
# Castro/Upper Market             15.0   7.0    1.0   NaN   4.0   NaN
# Chinatown                        2.0   3.0    7.0   NaN   2.0   NaN
# Excelsior                       23.0   3.0    3.0   1.0   1.0   NaN
# Financial District/South Beach   1.0   2.0    NaN   NaN  22.0   NaN
# Glen Park                        1.0   1.0    NaN   NaN   NaN   NaN
# Haight Ashbury                  22.0   4.0    2.0   NaN   NaN   NaN
# Hayes Valley                     8.0  14.0    6.0   NaN   7.0   NaN
# Inner Richmond                   2.0   4.0    3.0   NaN   2.0   NaN
# Inner Sunset                     1.0   3.0    4.0   2.0   NaN   NaN
# ...

# %%
df.file_date.value_counts()
# Out:
# 2019-06-27    34
# 2019-07-29    33
# 2020-02-28    30
# 2019-08-28    29
# 2019-08-15    21
#               ..
# 2019-09-04     1
# 2020-04-28     1
# 2020-03-31     1
# 2020-03-03     1
# 2020-02-11     1
# Name: file_date, Length: 196, dtype: int64

# %%
dd = pd.read_csv("https://raw.githubusercontent.com/blmoore/blogR/master/data/measles_incidence.csv")
dd.head()
# Out:
#                  Weekly Measles Incidence, 1928-2003 Unnamed: 1 Unnamed: 2  \
# 0  Data provided by Project Tycho, Data Version 1...        NaN        NaN
# 1                                               YEAR       WEEK    ALABAMA
# 2                                               1928          1       3.67
# 3                                               1928          2       6.25
# 4                                               1928          3       7.95
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7   Unnamed: 8  \
# 0        NaN        NaN        NaN         NaN        NaN          NaN
# 1     ALASKA    ARIZONA   ARKANSAS  CALIFORNIA   COLORADO  CONNECTICUT
# 2          -        1.9       4.11        1.38       8.38          4.5
# 3          -        6.4       9.91         1.8       6.02            9
# 4          -        4.5      11.15        1.31       2.86         8.81
#
#   Unnamed: 9  ...   Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 46  \
# ...
