# %%
import pandas as pd
import altair as altair

# %%
df = pd.read_csv('https://data.sfgov.org/resource/5cei-gny5.csv')

# %%
df.head()
# Out:
#   eviction_id                                 address           city state  \
# 0     M200677           800 Block Of Van Ness  Avenue  San Francisco    CA
# 1     M200682  300 Block Of Executive Park  Boulevard  San Francisco    CA
# 2     M200679             500 Block Of Jessie  Street  San Francisco    CA
# 3     M200680         900 Block Of Divisadero  Street  San Francisco    CA
# 4     M200681           1100 Block Of Mission  Street  San Francisco    CA
#
#      zip                file_date  non_payment  breach  nuisance  illegal_use  \
# 0  94109  2020-05-06T00:00:00.000        False    True     False        False
# 1  94134  2020-05-06T00:00:00.000        False   False      True        False
# 2  94103  2020-05-06T00:00:00.000        False   False      True        False
# 3  94115  2020-05-06T00:00:00.000        False   False      True        False
# 4  94103  2020-05-06T00:00:00.000        False    True     False        False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   eviction_id                  1000 non-null   object
#  1   address                      1000 non-null   object
#  2   city                         1000 non-null   object
#  3   state                        1000 non-null   object
#  4   zip                          1000 non-null   int64
#  5   file_date                    1000 non-null   object
#  6   non_payment                  1000 non-null   bool
#  7   breach                       1000 non-null   bool
#  8   nuisance                     1000 non-null   bool
#  9   illegal_use                  1000 non-null   bool
#  10  failure_to_sign_renewal      1000 non-null   bool
#  11  access_denial                1000 non-null   bool
#  12  unapproved_subtenant         1000 non-null   bool
# ...

# %%
df.zip.value_counts()
# Out:
# 94132    184
# 94109    102
# 94110     93
# 94102     77
# 94103     67
# 94112     66
# 94117     47
# 94122     43
# 94121     42
# 94133     38
# 94114     30
# 94134     30
# 94116     28
# 94124     25
# 94123     23
# 94105     23
# 94115     23
# 94118     20
# 94131     10
# 94108      9
# 94111      7
# 94107      7
# 94127      5
# 94104      1
# Name: zip, dtype: int64

# %%
df.zip.value_counts().sort_values().plot(kind = 'bar')

# %%
zips = [94132, 94109, 94110, 94102, 94103, 94112]

# %%
top6 = df[df.zip.isin(zips)]

# %%
top6.shape
# Out:
# (589, 43)

# %%
df.zip.nunique()
# Out:
# 24

# %%
top6.non_payment.value_counts()
# Out:
# False    560
# True      29
# Name: non_payment, dtype: int64

# %%
top6.neighborhood.value_counts()
# Out:
# Lakeshore                     180
# Mission                       108
# Tenderloin                     78
# Nob Hill                       41
# South of Market                33
# Excelsior                      28
# Oceanview/Merced/Ingleside     22
# Hayes Valley                   21
# Russian Hill                   19
# Bernal Heights                 16
# Outer Mission                  14
# Western Addition                5
# Pacific Heights                 5
# West of Twin Peaks              2
# Marina                          2
# Castro/Upper Market             2
# Noe Valley                      2
# Glen Park                       1
# Mission Bay                     1
# Bayview Hunters Point           1
# Name: neighborhood, dtype: int64

# %%
ls = top6[top6.neighborhood == 'Lakeshore']

# %%
ls = ls[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]

# %%
ls.head()
# Out:
#      non_payment  breach  nuisance  illegal_use  failure_to_sign_renewal  \
# 49         False   False      True        False                    False
# 54         False    True     False        False                    False
# 114        False    True     False        False                    False
# 115        False    True     False        False                    False
# 116        False    True     False        False                    False
#
#      access_denial  unapproved_subtenant  owner_move_in  demolition  \
# 49           False                 False          False       False
# 54           False                 False          False       False
# 114          False                 False          False       False
# 115          False                 False          False       False
# 116          False                 False          False       False
#
#      capital_improvement  substantial_rehab  ellis_act_withdrawal  \
# ...

# %%
ls1 = ls.melt(var_name='columns', value_name='index')

# %%
pd.crosstab(index=ls1['index'], columns=ls1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False              180       5                  180               180
# True                 0     175                    0                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False           180          180                   180
# True              0            0                     0
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                        180                  180          179
# True                           0                    0            1
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False              180               180          180       177          180
# True                 0                 0            0         3            0
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
td = top6[top6.neighborhood == 'Tenderloin']

# %%
td = td[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]

# %%
td1 = td.melt(var_name='columns', value_name='index')

# %%
pd.crosstab(index=td1['index'], columns=td1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               78      64                   76                78
# True                 0      14                    2                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            78           78                    78
# True              0            0                     0
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         78                   78           77
# True                           0                    0            1
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               78                78           72        22           77
# True                 0                 0            6        56            1
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
ms = top6[top6.neighborhood == 'Mission']

# %%
ms = ms[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]

# %%
ms1 = ms.melt(var_name='columns', value_name='index')

# %%
pd.crosstab(index=ms1['index'], columns=ms1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False              106      95                  106               108
# True                 2      13                    2                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False           107          108                    86
# True              1            0                    22
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                        108                  108          107
# True                           0                    0            1
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False              107               108          102        68          107
# True                 1                 0            6        40            1
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
nh = top6[top6.neighborhood == 'Nob Hill']

# %%
nh = nh[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]

# %%
nh1 = nh.melt(var_name='columns', value_name='index')

# %%
pd.crosstab(index=nh1['index'], columns=nh1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               41      37                   32                41
# True                 0       4                    9                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            41           41                    41
# True              0            0                     0
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         41                   41           41
# True                           0                    0            0
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               40                41           38        18           41
# True                 1                 0            3        23            0
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
df.neighborhood.value_counts().head(6)
# Out:
# Lakeshore          180
# Mission            109
# Tenderloin          78
# Sunset/Parkside     53
# Nob Hill            46
# Outer Richmond      41
# Name: neighborhood, dtype: int64

# %%
sp = df[df.neighborhood == 'Sunset/Parkside']

# %%
sp = sp[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]

# %%
sp1 = sp.melt(var_name='columns', value_name='index')

# %%
pd.crosstab(index=sp1['index'], columns=sp1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               53      44                   53                53
# True                 0       9                    0                 0
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            52           53                    48
# True              1            0                     5
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         53                   53           53
# True                           0                    0            0
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               51                53           52        37           50
# True                 2                 0            1        16            3
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
ori = df[df.neighborhood == 'Outer Richmond']

# %%
ori = ori[['non_payment','breach','nuisance','illegal_use','failure_to_sign_renewal','access_denial','unapproved_subtenant','owner_move_in','demolition','capital_improvement','substantial_rehab','ellis_act_withdrawal','condo_conversion','roommate_same_unit','other_cause','late_payments','lead_remediation','development','good_samaritan_ends']]

# %%
ori1 = ori.melt(var_name='columns', value_name='index')

# %%
pd.crosstab(index=ori1['index'], columns=ori1['columns'])
# Out:
# columns  access_denial  breach  capital_improvement  condo_conversion  \
# index
# False               40      29                   38                40
# True                 1      12                    3                 1
#
# columns  demolition  development  ellis_act_withdrawal  \
# index
# False            41           41                    40
# True              0            0                     1
#
# columns  failure_to_sign_renewal  good_samaritan_ends  illegal_use  \
# index
# False                         41                   41           40
# True                           0                    0            1
#
# columns  late_payments  lead_remediation  non_payment  nuisance  other_cause  \
# index
# False               40                41           38        34           41
# True                 1                 0            3         7            0
#
# columns  owner_move_in  roommate_same_unit  substantial_rehab  \
# index
# ...

# %%
nei = df[df.zip == 94102]

# %%
nei.neighborhood.value_counts()
# Out:
# Tenderloin          48
# Hayes Valley        21
# Mission              5
# Nob Hill             1
# Western Addition     1
# Name: neighborhood, dtype: int64
